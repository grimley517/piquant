# %% [markdown]
# # Python for algorithmic trading
#
# Workthrough of book.

# %%
print("hello")
# %pip install certifi notebook matplotlib
# %pip install "openbb[all]"
# Out:
# hello
# ...
#   Using cached notebook-7.3.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached jupyterlab-4.3.4-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached jupyter_events-0.11.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached nbconvert-7.16.5-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# ...

# %%
from src import getDataFrame as ds

data = ds.getDataFrame("SPY")
print(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src import getDataFrame as ds
#       3 data = ds.getDataFrame("SPY")
#       4 print(data)
#
# File ~/Projects/piquant/src/getDataFrame.py:1
# ----> 1 from openbb import obb
#       3 def getDataFrameForSymbol(symbol):
#       4     obb.user.preferences.output_type = "dataframe"
#
# File /opt/homebrew/lib/python3.11/site-packages/openbb/__init__.py:8
#       5 from pathlib import Path
#       6 from typing import List, Optional, Union
# ----> 8 from openbb_core.app.static.app_factory import (
#       9     BaseApp as _BaseApp,
#      10     create_app as _create_app,
#      11 )
#      12 from openbb_core.app.static.package_builder import PackageBuilder as _PackageBuilder
#      13 from openbb_core.app.static.reference_loader import ReferenceLoader as _ReferenceLoader
#
# ...
